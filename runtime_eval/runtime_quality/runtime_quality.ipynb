# %%
# %load_ext autoreload
# %autoreload 2

# %%
PATH = '/mnt/pg_lip_bloom/runtime_eval/'
import sys
sys.path.append(PATH)

from core.eval_Runtime import *

# %%
query_dirs = {
    # 'imdb': '/mnt/ml4qo/dataset/imdb/job/',
    # 'imdb': '/mnt/ml4qo/lip_db/lip_db_test_queries/job/import sys
',
    # 'imdb_pg_lip': '/mnt/ml4qo/lip_db/lip_db_test_queries/job_pg_lip/',
    # 'imdb_balsa': '/mnt/ml4qo/lip_db/lip_db_test_queries/job_balsa/',
    
    'imdb': '/mnt/pg_lip_bloom/queries/job/',
    
    'imdb_pg_lip': '/mnt/pg_lip_bloom/queries/job_pg_lip/',
    'imdb_pg_lip_adaptive_build': '/mnt/pg_lip_bloom/queries/job_pg_lip_adapt_build/',
    
    'imdb_balsa': '/mnt/pg_lip_bloom/queries/job_balsa/',
    'imdb_balsa_slow_test': '/mnt/pg_lip_bloom/queries/job_balsa_slow_test/take{}/',
    'imdb_balsa_rand_test': '/mnt/pg_lip_bloom/queries/job_balsa_rand_test/take{}/',
    
    'imdb_pg_lip_balsa': '/mnt/pg_lip_bloom/queries/job_pg_lip_balsa/',
    'imdb_pg_balsa_jo': '/mnt/pg_lip_bloom/queries/job_pg_balsa_jo/',
    'imdb_pg_balsa_test_jo': '/mnt/pg_lip_bloom/queries/job_balsa_slow_test_jo/',
    
    
    'imdb_pg_balsa_op': '/mnt/pg_lip_bloom/queries/job_pg_balsa_op/',
    
    'imdbload_no_fk': '/mnt/pg_lip_bloom/queries/job/',
    'imdbload_no_fk_pg_lip': '/mnt/pg_lip_bloom/queries/job_pg_lip/',
    
    
    'imdb_balsa_test_join_group':  '/mnt/pg_lip_bloom/queries/JOB_test_n_join_group_{}/take{}/',
    
    'imdb_balsa_eval_cost_model': '/mnt/pg_lip_bloom/queries/job_balsa_eval_cost_model/{}/',
    'imdb_balsa_eval_cost_model_touched': '/mnt/pg_lip_bloom/queries/job_balsa_eval_cost_model/{}_balsa_touched/',
    
    
    'imdb_balsa_eval_join_group': '/mnt/pg_lip_bloom/queries/JOB_test_n_join_group_{}/take{}/',
    
    'imdb_balsa_all_train': '/mnt/pg_lip_bloom/queries/job_balsa_all_train/take{}/'
    
    # 'imdb_fk': '/mnt/ml4qo/dataset/imdb/job/',
    # 'job_first': '/mnt/ml4qo/dataset/imdb/job-first/',
    # 'tpch_sf1': '/mnt/ml4qo/dataset/tpch/tpch-dbgen/queries/generated_queries',
    # 'ssb_pg_lip': '/mnt/ml4qo/lip_db/lip_db_test_queries/ssb_pg_lip/',
    # 'ssb_pg_lip_orig': '/mnt/ml4qo/lip_db/lip_db_test_queries/ssb/'
}

# job_slow_queries = [
#     '6d.sql', '6f.sql', '8c.sql', '9d.sql', 
#     '10c.sql', '16b.sql', '17a.sql', '17e.sql', '17f.sql', '17b.sql', '17c.sql', '17d.sql', 
#     '18c.sql', '19c.sql', '19d.sql', 
#     '20a.sql', '26c.sql', '25c.sql', 
#     '30a.sql'
# ]

job_slow_queries = [
    '6d.sql', 
    '6f.sql', 
    '8c.sql', '9d.sql', 
    '10c.sql', 
    '16b.sql', 
    '17a.sql', '17b.sql',  
    '17c.sql', 
    '17d.sql',  
    '17e.sql', 
    '17f.sql',  
    '18c.sql', '19c.sql', '19d.sql', 
    '20a.sql', 
    '25c.sql', '26c.sql', 
    '30a.sql'
]

all_JOB_queries = [
    '30a.sql', '1d.sql', '25a.sql', '6b.sql', '19c.sql', '28b.sql', 
    '9b.sql', '33b.sql', '32a.sql', '27a.sql', '20b.sql', '17d.sql', 
    '16b.sql', '10b.sql', '6a.sql', '17b.sql', '25b.sql', '8b.sql', 
    '31b.sql', '33c.sql', '23a.sql', '15a.sql', '21b.sql', '11d.sql', 
    '9a.sql', '6d.sql', '24a.sql', '17e.sql', '19a.sql', '1c.sql', 
    '25c.sql', '31a.sql', '23c.sql', '17f.sql', '19b.sql', '9d.sql', 
    '27b.sql', '11b.sql', '7b.sql', '19d.sql', '1a.sql', '11c.sql', 
    '31c.sql', '28a.sql', '3c.sql', '6c.sql', '26b.sql', '16a.sql', 
    '7a.sql', '29b.sql', '29a.sql', '1b.sql', '6e.sql', '13d.sql', 
    '10c.sql', '26a.sql', '4b.sql', '10a.sql', '15b.sql', '15d.sql', 
    '26c.sql', '14b.sql', '15c.sql', '14c.sql', '13b.sql', '3a.sql', 
    '24b.sql', '5a.sql', '8c.sql', '6f.sql', '8a.sql', '27c.sql', 
    '12a.sql', '22a.sql', '17a.sql', '13a.sql', '21a.sql', '12b.sql', 
    '13c.sql', '8d.sql', '21c.sql', '7c.sql', '2a.sql', '3b.sql', 
    '16c.sql', '9c.sql', '32b.sql', '28c.sql', '33a.sql', '11a.sql', 
    '18a.sql', '5c.sql', '22d.sql', '18c.sql', '5b.sql', '2c.sql', 
    '16d.sql', '4a.sql', '22c.sql', '12c.sql', '29c.sql', '30b.sql', 
    '2d.sql', '14a.sql', '17c.sql', '22b.sql', '30c.sql', '20a.sql', 
    '20c.sql', '2b.sql', '4c.sql', '18b.sql', '23b.sql'
]

# %% [markdown]
# ## PG original

# %%
engine_name = 'postgres'
db_name = 'ssb_sf10'
query_dir = query_dirs['ssb_pg_lip_orig']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir, 
                       # sql_files=[ '13.sql'],
                       save_json_file=f'./{engine_name}_parallel=1_{db_name}_runtimes.json', 
                      rerun_finished=True,
                      disable_parallel=False,
                      multiple_runs=5)
# Out:
# INFO:root:Evaluating 1.sql.
# INFO:root:	Finished the 1-th trial with 3.05 secs
# INFO:root:	Finished the 2-th trial with 2.92 secs
# INFO:root:	Avg runtime = 2.99 secs
# INFO:root:Evaluating 10.sql.
# INFO:root:	Finished the 1-th trial with 5.71 secs
# INFO:root:	Finished the 2-th trial with 6.09 secs
# INFO:root:	Avg runtime = 5.90 secs
# INFO:root:Evaluating 11.sql.
# INFO:root:	Finished the 1-th trial with 2.82 secs
# INFO:root:	Finished the 2-th trial with 2.65 secs
# INFO:root:	Avg runtime = 2.73 secs
# INFO:root:Evaluating 12.sql.
# INFO:root:	Finished the 1-th trial with 2.50 secs
# INFO:root:	Finished the 2-th trial with 2.47 secs
# INFO:root:	Avg runtime = 2.48 secs
# INFO:root:Evaluating 13.sql.
# INFO:root:	Finished the 1-th trial with 55.43 secs
# INFO:root:	Finished the 2-th trial with 55.91 secs
# INFO:root:	Avg runtime = 55.67 secs
# INFO:root:Evaluating 14.sql.
# INFO:root:	Finished the 1-th trial with 14.67 secs
# INFO:root:	Finished the 2-th trial with 16.62 secs
# ...

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       sql_files=all_JOB_queries,
                       # skip_queries=['21a.sql', '21b.sql', '21c.sql', '24a.sql', '27a.sql', '27b.sql', '27d.sql', '27c.sql'],
                       save_json_file=f'./{engine_name}_parallel=1_{db_name}_runtimes.json', 
                      rerun_finished=False,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=False)
# Out:
# INFO:root:Evaluating 17a.sql.
# INFO:root:	Finished the 1-th trial with 10.02 secs
# INFO:root:	Finished the 2-th trial with 8.85 secs
# INFO:root:	Finished the 3-th trial with 9.00 secs
# INFO:root:	Finished the 4-th trial with 9.04 secs
# INFO:root:	Finished the 5-th trial with 8.81 secs
# INFO:root:	Avg runtime = 9.14 secs
# {'30a.sql': [2.6145, 2.04146, 1.9994090000000002, 1.987144, 1.979729],
#  '1d.sql': [0.10658, 0.104377, 0.100845, 0.102144, 0.10033],
#  '25a.sql': [2.160478,
#   1.8008199999999999,
#   1.7974890000000001,
#   1.806655,
#   1.793858],
#  '6b.sql': [0.175455, 0.13023099999999999, 0.132519, 0.138173, 0.132668],
#  '19c.sql': [0.42334,
#   0.40666599999999997,
#   0.39009699999999997,
#   0.387852,
#   0.379552],
#  '28b.sql': [0.356176, 0.350317, 0.353948, 0.350036, 0.351176],
#  '9b.sql': [0.9033049999999999,
#   0.8642029999999999,
#   0.8571169999999999,
#   0.838118,
#   0.8303619999999999],
# ...

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload_no_fk'
query_dir = query_dirs[db_name]

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       # sql_files=job_slow_queries,
                       skip_queries=['21a.sql', '21b.sql', '21c.sql', '24a.sql', '27a.sql', 
                                     '27b.sql', '27d.sql', '27c.sql',
                                    '28b.sql', '29a.sql', '29c.sql'],
                       save_json_file=f'./{engine_name}_parallel=1_{db_name}_runtimes.json', 
                      rerun_finished=False,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=True,
                      save_plan_subdir='plan_no_fk_idx')
# Out:
# INFO:root:Evaluating 1a.sql.
# INFO:root:	Finished the 1-th trial with 0.34 secs
# INFO:root:	Finished the 2-th trial with 0.32 secs
# INFO:root:	Finished the 3-th trial with 0.31 secs
# INFO:root:	Finished the 4-th trial with 0.30 secs
# INFO:root:	Finished the 5-th trial with 0.29 secs
# INFO:root:	Avg runtime = 0.31 secs
# INFO:root:Evaluating 1b.sql.
# INFO:root:	Finished the 1-th trial with 0.21 secs
# INFO:root:	Finished the 2-th trial with 0.21 secs
# INFO:root:	Finished the 3-th trial with 0.21 secs
# INFO:root:	Finished the 4-th trial with 0.21 secs
# INFO:root:	Finished the 5-th trial with 0.20 secs
# INFO:root:	Avg runtime = 0.21 secs
# INFO:root:Evaluating 1c.sql.
# INFO:root:	Finished the 1-th trial with 0.25 secs
# INFO:root:	Finished the 2-th trial with 0.25 secs
# INFO:root:	Finished the 3-th trial with 0.26 secs
# INFO:root:	Finished the 4-th trial with 0.25 secs
# INFO:root:	Finished the 5-th trial with 0.24 secs
# INFO:root:	Avg runtime = 0.25 secs
# ...

# %% [markdown]
# ## PG w/ LIP

# %%
engine_name = 'postgres_pg_lip'
db_name = 'ssb_sf10'
query_dir = query_dirs['ssb_pg_lip']
init_sql_file= '/mnt/ml4qo/lip_db/lip_db_test_queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(
    save_json_file=f'./{engine_name}_parallel=1_{db_name}_runtimes.json', 
                      rerun_finished=True,
                      disable_parallel=False, 
                        multiple_runs=2)
# Out:
# INFO:root:Evaluating 1.sql.
# INFO:root:	Finished the 1-th trial with total: 3.07 secs, (prep: 0.08, exec: 2.97)
# INFO:root:	Finished the 2-th trial with total: 2.92 secs, (prep: 0.08, exec: 2.82)
# INFO:root:Evaluating 10.sql.
# INFO:root:	Finished the 1-th trial with total: 5.83 secs, (prep: 0.23, exec: 5.51)
# INFO:root:	Finished the 2-th trial with total: 5.86 secs, (prep: 0.21, exec: 5.55)
# INFO:root:Evaluating 11.sql.
# INFO:root:	Finished the 1-th trial with total: 3.03 secs, (prep: 0.21, exec: 2.82)
# INFO:root:	Finished the 2-th trial with total: 3.03 secs, (prep: 0.21, exec: 2.82)
# INFO:root:Evaluating 12.sql.
# INFO:root:	Finished the 1-th trial with total: 2.99 secs, (prep: 0.20, exec: 2.80)
# INFO:root:	Finished the 2-th trial with total: 3.01 secs, (prep: 0.20, exec: 2.81)
# INFO:root:Evaluating 13.sql.
# INFO:root:	Finished the 1-th trial with total: 49.06 secs, (prep: 0.52, exec: 47.26)
# ...

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_lip']
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./{engine_name}_non_adaptive_parallel=1_{db_name}_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      multiple_runs=2, 
                      save_plan=False)
# Out:
# INFO:root:Evaluating 6d.sql.
# INFO:root:	Finished the 1-th trial with total: 3.03 secs, (prep: 0.88, exec: 1.61)
# INFO:root:	Finished the 2-th trial with total: 2.36 secs, (prep: 0.82, exec: 1.00)
# INFO:root:Evaluating 6f.sql.
# INFO:root:	Finished the 1-th trial with total: 5.17 secs, (prep: 0.57, exec: 4.25)
# INFO:root:	Finished the 2-th trial with total: 5.04 secs, (prep: 0.56, exec: 4.13)
# INFO:root:Evaluating 8c.sql.
# INFO:root:	Finished the 1-th trial with total: 4.26 secs, (prep: 0.11, exec: 3.78)
# INFO:root:	Finished the 2-th trial with total: 4.23 secs, (prep: 0.10, exec: 3.77)
# INFO:root:Evaluating 9d.sql.
# INFO:root:	Finished the 1-th trial with total: 7.37 secs, (prep: 2.17, exec: 4.51)
# INFO:root:	Finished the 2-th trial with total: 7.13 secs, (prep: 2.11, exec: 4.31)
# INFO:root:Evaluating 10c.sql.
# INFO:root:	Finished the 1-th trial with total: 3.41 secs, (prep: 2.41, exec: 0.32)
# ...

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_lip_adaptive_build']
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./{engine_name}_adaptive_build_parallel=1_{db_name}_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      multiple_runs=3, 
                      save_plan=False)
# Out:
# INFO:root:Evaluating 6d.sql.
# INFO:root:	Finished the 1-th trial with total: 2.60 secs, (prep: 0.36, exec: 1.70)
# INFO:root:	Finished the 2-th trial with total: 1.69 secs, (prep: 0.26, exec: 0.91)
# INFO:root:	Finished the 3-th trial with total: 1.68 secs, (prep: 0.26, exec: 0.91)
# INFO:root:Evaluating 6f.sql.
# INFO:root:	Finished the 1-th trial with total: 3.94 secs, (prep: 0.00, exec: 3.59)
# INFO:root:	Finished the 2-th trial with total: 3.77 secs, (prep: 0.00, exec: 3.43)
# INFO:root:	Finished the 3-th trial with total: 3.81 secs, (prep: 0.00, exec: 3.46)
# INFO:root:Evaluating 8c.sql.
# INFO:root:	Finished the 1-th trial with total: 4.20 secs, (prep: 0.00, exec: 3.84)
# INFO:root:	Finished the 2-th trial with total: 3.99 secs, (prep: 0.00, exec: 3.64)
# INFO:root:	Finished the 3-th trial with total: 3.98 secs, (prep: 0.00, exec: 3.63)
# INFO:root:Evaluating 9d.sql.
# INFO:root:	Finished the 1-th trial with total: 3.90 secs, (prep: 0.00, exec: 3.20)
# ...

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload_no_fk'
query_dir = query_dirs['imdb_pg_lip']
init_sql_file= '/mnt/ml4qo/lip_db/lip_db_test_queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file= f'./{engine_name}_parallel=1_{db_name}_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      disable_parallel=False, 
                      multiple_runs=5, 
                      save_plan=True,
                      save_plan_subdir='plan_no_fk_idx')

# %% [markdown]
# # PG w/ LIP + tune op

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_lip_adaptive_build']
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./{engine_name}_adaptive_build_parallel=1_{db_name}_disable_nl_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      multiple_runs=3, 
                      save_plan=False,
                      disable_op='nestloop')
# Out:
# INFO:root:Evaluating 6d.sql.
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 1-th trial with total: 3.08 secs, (prep: 0.28, exec: 2.26)
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 2-th trial with total: 2.99 secs, (prep: 0.23, exec: 2.23)
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 3-th trial with total: 3.00 secs, (prep: 0.25, exec: 2.20)
# INFO:root:Evaluating 6f.sql.
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 1-th trial with total: 3.59 secs, (prep: 0.00, exec: 3.23)
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 2-th trial with total: 3.57 secs, (prep: 0.00, exec: 3.21)
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 3-th trial with total: 3.59 secs, (prep: 0.00, exec: 3.23)
# INFO:root:Evaluating 8c.sql.
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 1-th trial with total: 4.65 secs, (prep: 0.00, exec: 4.28)
# ...

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_lip_adaptive_build']
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./{engine_name}_adaptive_build_parallel=1_{db_name}_disable_mj_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      multiple_runs=3, 
                      save_plan=False,
                      disable_op='mergejoin')
# Out:
# INFO:root:Evaluating 6d.sql.
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 1-th trial with total: 2.46 secs, (prep: 0.28, exec: 1.63)
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 2-th trial with total: 1.77 secs, (prep: 0.24, exec: 1.01)
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 3-th trial with total: 1.77 secs, (prep: 0.23, exec: 1.02)
# INFO:root:Evaluating 6f.sql.
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 1-th trial with total: 4.29 secs, (prep: 0.00, exec: 3.94)
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 2-th trial with total: 4.14 secs, (prep: 0.00, exec: 3.79)
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 3-th trial with total: 4.16 secs, (prep: 0.00, exec: 3.80)
# INFO:root:Evaluating 8c.sql.
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 1-th trial with total: 4.15 secs, (prep: 0.00, exec: 3.78)
# ...

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_lip_adaptive_build']
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./{engine_name}_adaptive_build_parallel=1_{db_name}_disable_nl_mj_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      multiple_runs=3, 
                      save_plan=False,
                      disable_op='both')
# Out:
# INFO:root:Evaluating 6d.sql.
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 1-th trial with total: 3.11 secs, (prep: 0.28, exec: 2.29)
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 2-th trial with total: 3.01 secs, (prep: 0.23, exec: 2.24)
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 3-th trial with total: 2.96 secs, (prep: 0.23, exec: 2.19)
# INFO:root:Evaluating 6f.sql.
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 1-th trial with total: 3.59 secs, (prep: 0.00, exec: 3.23)
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 2-th trial with total: 3.57 secs, (prep: 0.00, exec: 3.21)
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 3-th trial with total: 3.64 secs, (prep: 0.00, exec: 3.27)
# INFO:root:Evaluating 8c.sql.
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 1-th trial with total: 4.65 secs, (prep: 0.00, exec: 4.29)
# WARNING:root:both join is disabled.
# ...

# %% [markdown]
# # PG lip with Adaptive join

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = '/mnt/pg_lip_bloom/queries/job_pg_lip_adaptive_join/'
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./{engine_name}_adaptive_join_parallel=1_{db_name}_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=False,
                      multiple_runs=3, 
                      save_plan=False)
# Out:
# INFO:root:Evaluating 30a.sql.
# INFO:root:	Finished the 1-th trial with total: 11.63 secs, (prep: 1.08, exec: 8.78)
# INFO:root:	Finished the 2-th trial with total: 9.49 secs, (prep: 0.75, exec: 7.04)
# INFO:root:	Finished the 3-th trial with total: 9.27 secs, (prep: 0.74, exec: 6.83)
# {'6d.sql': [[1.2246990203857422, 0.27555298805236816, 0.4200925827026367],
#   [1.143676519393921, 0.24498701095581055, 0.39046359062194824],
#   [1.1355087757110596, 0.23964548110961914, 0.39176106452941895]],
#  '6f.sql': [[2.767164945602417, 0, 2.4194118976593018],
#   [2.7286324501037598, 0, 2.360645294189453],
#   [2.6808128356933594, 0, 2.339932918548584]],
#  '8c.sql': [[6.377743721008301, 0, 6.030604124069214],
#   [6.16583251953125, 0, 5.775527715682983],
#   [6.049539566040039, 0, 5.712187051773071]],
#  '9d.sql': [[3.3543028831481934, 0, 2.6857244968414307],
#   [3.3364791870117188, 0, 2.6583499908447266],
#   [3.293958902359009, 0, 2.624880075454712]],
# ...

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = '/mnt/pg_lip_bloom/queries/job_pg_lip_adaptive_join/pg_jo/'
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./{engine_name}_adaptive_join_pg_jo_parallel=1_{db_name}_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=False,
                      multiple_runs=3, 
                      save_plan=False)
# Out:
# INFO:root:Evaluating 6d.sql.
# INFO:root:	Finished the 1-th trial with total: 2.30 secs, (prep: 0.26, exec: 1.53)
# INFO:root:	Finished the 2-th trial with total: 1.69 secs, (prep: 0.24, exec: 0.93)
# INFO:root:	Finished the 3-th trial with total: 1.67 secs, (prep: 0.25, exec: 0.91)
# INFO:root:Evaluating 6f.sql.
# INFO:root:	Finished the 1-th trial with total: 2.53 secs, (prep: 0.00, exec: 2.19)
# INFO:root:	Finished the 2-th trial with total: 2.44 secs, (prep: 0.00, exec: 2.10)
# INFO:root:	Finished the 3-th trial with total: 2.42 secs, (prep: 0.00, exec: 2.08)
# INFO:root:Evaluating 8c.sql.
# INFO:root:	Finished the 1-th trial with total: 3.52 secs, (prep: 0.00, exec: 3.18)
# INFO:root:	Finished the 2-th trial with total: 3.37 secs, (prep: 0.00, exec: 3.02)
# INFO:root:	Finished the 3-th trial with total: 3.32 secs, (prep: 0.00, exec: 2.98)
# INFO:root:Evaluating 9d.sql.
# INFO:root:	Finished the 1-th trial with total: 4.04 secs, (prep: 0.00, exec: 3.36)
# ...

# %% [markdown]
# # PG w/ Balsa

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_balsa_slow_test']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       sql_files=job_slow_queries,
                       #skip_queries=['21a.sql', '21b.sql', '21c.sql', '24a.sql', '27a.sql', '27b.sql', '27d.sql', '27c.sql'],
                       save_json_file=f'./{engine_name}_parallel=1_{db_name}_balsa_slow_test_runtimes.json', 
                      rerun_finished=False,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=True)
# Out:
# INFO:root:Evaluating 6d.sql.
# INFO:root:	Finished the 1-th trial with 154.23 secs
# INFO:root:	Finished the 2-th trial with 7.25 secs
# INFO:root:	Finished the 3-th trial with 7.20 secs
# INFO:root:	Finished the 4-th trial with 7.25 secs
# INFO:root:	Finished the 5-th trial with 7.20 secs
# INFO:root:	Avg runtime = 36.63 secs
# INFO:root:Evaluating 8c.sql.
# INFO:root:	Finished the 1-th trial with 16.41 secs
# INFO:root:	Finished the 2-th trial with 6.89 secs
# INFO:root:	Finished the 3-th trial with 7.03 secs
# INFO:root:	Finished the 4-th trial with 6.95 secs
# INFO:root:	Finished the 5-th trial with 6.89 secs
# INFO:root:	Avg runtime = 8.83 secs
# INFO:root:Evaluating 9d.sql.
# INFO:root:	Finished the 1-th trial with 39.76 secs
# INFO:root:	Finished the 2-th trial with 3.12 secs
# INFO:root:	Finished the 3-th trial with 3.04 secs
# INFO:root:	Finished the 4-th trial with 3.04 secs
# INFO:root:	Finished the 5-th trial with 3.03 secs
# INFO:root:	Avg runtime = 10.40 secs
# ...

# %%
# engine_name = 'postgres'
# # db_name = 'imdb'
# db_name = 'imdbload'
# query_dir = query_dirs['imdb_balsa']

# pg_db = DB_instance(engine_name, db_name)
# pg_ev = Runtime_Evaluator(pg_db, query_dir)
# pg_ev.evaluate_queries(sql_dir=query_dir,
#                        sql_files=job_slow_queries,
#                        #skip_queries=['21a.sql', '21b.sql', '21c.sql', '24a.sql', '27a.sql', '27b.sql', '27d.sql', '27c.sql'],
#                        save_json_file=f'./{engine_name}_parallel=1_{db_name}_balsa_disable_nl_runtimes.json', 
#                       rerun_finished=False,
#                       disable_parallel=False,
#                       multiple_runs=5,
#                       save_plan=True)

# %% [markdown]
# # PG + Balsa JO

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_balsa_jo']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       sql_files=job_slow_queries,
                       # skip_queries=['17c.sql', '20a.sql'],
                       save_json_file=f'./{engine_name}_balsa_jo_parallel=1_{db_name}_runtimes.json', 
                      rerun_finished=False,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=True)
# Out:
# INFO:root:Evaluating 16b.sql.
# INFO:root:	Finished the 1-th trial with 5.87 secs
# INFO:root:	Finished the 2-th trial with 5.77 secs
# INFO:root:	Finished the 3-th trial with 5.76 secs
# INFO:root:	Finished the 4-th trial with 5.70 secs
# INFO:root:	Finished the 5-th trial with 5.71 secs
# INFO:root:	Avg runtime = 5.76 secs
# INFO:root:Evaluating 17a.sql.
# INFO:root:	Finished the 1-th trial with 2.74 secs
# INFO:root:	Finished the 2-th trial with 2.71 secs
# INFO:root:	Finished the 3-th trial with 2.73 secs
# INFO:root:	Finished the 4-th trial with 2.75 secs
# INFO:root:	Finished the 5-th trial with 2.71 secs
# INFO:root:	Avg runtime = 2.73 secs
# INFO:root:Evaluating 17e.sql.
# INFO:root:	Finished the 1-th trial with 3.44 secs
# INFO:root:	Finished the 2-th trial with 3.50 secs
# INFO:root:	Finished the 3-th trial with 3.50 secs
# INFO:root:	Finished the 4-th trial with 3.53 secs
# INFO:root:	Finished the 5-th trial with 3.51 secs
# INFO:root:	Avg runtime = 3.49 secs
# ...

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_balsa_test_jo']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       sql_files=job_slow_queries,
                       # skip_queries=['17c.sql', '20a.sql'],
                       save_json_file=f'./{engine_name}_balsa_test_jo_parallel=1_{db_name}_runtimes.json', 
                      rerun_finished=False,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=True)
# Out:
# INFO:root:Evaluating 6d.sql.
# INFO:root:	Finished the 1-th trial with 161.30 secs
# INFO:root:	Finished the 2-th trial with 7.73 secs
# INFO:root:	Finished the 3-th trial with 7.72 secs
# INFO:root:	Finished the 4-th trial with 7.70 secs
# INFO:root:	Finished the 5-th trial with 7.77 secs
# INFO:root:	Avg runtime = 38.44 secs
# INFO:root:Evaluating 8c.sql.
# INFO:root:	Finished the 1-th trial with 5.61 secs
# INFO:root:	Finished the 2-th trial with 4.14 secs
# INFO:root:	Finished the 3-th trial with 4.05 secs
# INFO:root:	Finished the 4-th trial with 4.13 secs
# INFO:root:	Finished the 5-th trial with 3.94 secs
# INFO:root:	Avg runtime = 4.37 secs
# INFO:root:Evaluating 9d.sql.
# INFO:root:	Finished the 1-th trial with 28.66 secs
# INFO:root:	Finished the 2-th trial with 2.80 secs
# INFO:root:	Finished the 3-th trial with 2.77 secs
# INFO:root:	Finished the 4-th trial with 2.70 secs
# INFO:root:	Finished the 5-th trial with 2.75 secs
# INFO:root:	Avg runtime = 7.94 secs
# ...

# %% [markdown]
# # PG + Balsa OP

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_balsa_op']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       sql_files=job_slow_queries,
                       # skip_queries=['17c.sql', '20a.sql'],
                       save_json_file=f'./{engine_name}_balsa_op_parallel=1_{db_name}_runtimes.json', 
                      rerun_finished=True,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=True)

# %% [markdown]
# # Balsa all train

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_all_train']

for t in range(1, 5):
    query_dir = query_dir_template.format(t)
    print(f"Executing query {query_dir}")
    if os.path.isdir(query_dir):
        pg_db = DB_instance(engine_name, db_name)
        pg_ev = Runtime_Evaluator(pg_db, query_dir)
        pg_ev.evaluate_queries(sql_dir=query_dir,
                               # sql_files=job_slow_queries,
                               # skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                               save_json_file=f'./eval_join_group/{engine_name}_balsa_all_train_take{t}_runtimes.json', 
                              rerun_finished=False,
                              disable_parallel=False,
                              multiple_runs=2,
                              save_plan=False)
# Out:
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_all_train/take1/
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_all_train/take2/
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_all_train/take3/
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_all_train/take4/

# %% [markdown]
# ### JO

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_all_train']

# for group in range(1, 7): #, '17a']:
for take in range(1, 5):
    query_dir = query_dir_template.format(f'{take}')
    jo_query_dir = query_dir_template.format(f'{take}_jo')
    # print(jo_query_dir)

    if os.path.isdir(query_dir):
        for fname in os.listdir(query_dir):
            if 'sql' in fname:
                with open(os.path.join(query_dir, fname)) as f, open(os.path.join(jo_query_dir, fname), 'w') as g:
                    line = f.readline()
                    while line:
                        # print(line)
                        if 'HashJoin' in line or 'NestLoop' in line or 'MergeJoin' in line or 'SeqScan' in line or 'IndexScan' in line:
                            if '/*+' in line:
                                g.write('/*+\n')
                                # print('/*+\n')
                        else:
                            g.write(line)
                            # print(line)
                        line = f.readline()
        pass
    else:
        print(query_dir, ' not found.')

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_all_train']

for t in range(1, 5):
    query_dir = query_dir_template.format(f'{t}_jo')
    print(f"Executing query {query_dir}")
    if os.path.isdir(query_dir):
        pg_db = DB_instance(engine_name, db_name)
        pg_ev = Runtime_Evaluator(pg_db, query_dir)
        pg_ev.evaluate_queries(sql_dir=query_dir,
                               # sql_files=job_slow_queries,
                               # skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                               save_json_file=f'./eval_join_group/{engine_name}_balsa_all_train_take{t}_jo_runtimes.json', 
                              rerun_finished=False,
                              disable_parallel=False,
                              multiple_runs=2,
                              save_plan=False)
# Out:
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_all_train/take1_jo/
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_all_train/take2_jo/
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_all_train/take3_jo/
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_all_train/take4_jo/
# INFO:root:Evaluating 26a.sql.
# INFO:root:	Finished the 1-th trial with 0.43 secs
# INFO:root:	Finished the 2-th trial with 0.27 secs
# INFO:root:	Avg runtime = 0.35 secs
# INFO:root:Evaluating 26b.sql.
# INFO:root:	Finished the 1-th trial with 0.12 secs
# INFO:root:	Finished the 2-th trial with 0.12 secs
# INFO:root:	Avg runtime = 0.12 secs
# INFO:root:Evaluating 26c.sql.
# INFO:root:	Finished the 1-th trial with 0.76 secs
# INFO:root:	Finished the 2-th trial with 0.58 secs
# INFO:root:	Avg runtime = 0.67 secs
# INFO:root:Evaluating 27a.sql.
# INFO:root:	Finished the 1-th trial with 0.02 secs
# INFO:root:	Finished the 2-th trial with 0.02 secs
# INFO:root:	Avg runtime = 0.02 secs
# ...

# %% [markdown]
# # Balsa slow test

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_slow_test']

for t in range(1, 5):
    t = 5
    query_dir = query_dir_template.format(t)
    print(f"Executing query {query_dir}")
    if os.path.isdir(query_dir):
        pg_db = DB_instance(engine_name, db_name)
        pg_ev = Runtime_Evaluator(pg_db, query_dir)
        pg_ev.evaluate_queries(sql_dir=query_dir,
                               # sql_files=job_slow_queries,
                               # skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                               save_json_file=f'./eval_join_group/{engine_name}_balsa_slow_test_take{t}_runtimes.json', 
                              rerun_finished=True,
                              disable_parallel=False,
                              multiple_runs=2,
                              save_plan=False)
    break
# Out:
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_slow_test/take5/
# INFO:root:Evaluating 10c.sql.
# INFO:root:	Finished the 1-th trial with 12.51 secs
# INFO:root:	Finished the 2-th trial with 11.06 secs
# INFO:root:	Avg runtime = 11.79 secs
# INFO:root:Evaluating 16b.sql.
# INFO:root:	Finished the 1-th trial with 4.34 secs
# INFO:root:	Finished the 2-th trial with 4.60 secs
# INFO:root:	Avg runtime = 4.47 secs
# INFO:root:Evaluating 17a.sql.
# INFO:root:	Finished the 1-th trial with 2.59 secs
# INFO:root:	Finished the 2-th trial with 2.69 secs
# INFO:root:	Avg runtime = 2.64 secs
# INFO:root:Evaluating 17b.sql.
# INFO:root:	Finished the 1-th trial with 1.38 secs
# INFO:root:	Finished the 2-th trial with 1.36 secs
# INFO:root:	Avg runtime = 1.37 secs
# INFO:root:Evaluating 17c.sql.
# INFO:root:	Finished the 1-th trial with 1.46 secs
# INFO:root:	Finished the 2-th trial with 1.37 secs
# INFO:root:	Avg runtime = 1.41 secs
# INFO:root:Evaluating 17d.sql.
# ...

# %% [markdown]
# ### JO

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_slow_test']

# for group in range(1, 7): #, '17a']:
for take in range(1, 6):
    query_dir = query_dir_template.format(f'{take}')
    jo_query_dir = query_dir_template.format(f'{take}_jo')

    if os.path.isdir(query_dir):
        for fname in os.listdir(query_dir):
            if 'sql' in fname:
                with open(os.path.join(query_dir, fname)) as f, open(os.path.join(jo_query_dir, fname), 'w') as g:
                    line = f.readline()
                    while line:
                        # print(line)
                        if 'HashJoin' in line or 'NestLoop' in line or 'MergeJoin' in line or 'SeqScan' in line or 'IndexScan' in line:
                            if '/*+' in line:
                                g.write('/*+\n')
                                # print('/*+\n')
                        else:
                            g.write(line)
                            # print(line)
                        line = f.readline()
        pass
    else:
        print(query_dir, ' not found.')
    # break

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_slow_test']

for t in range(1, 5):
    t = 5
    query_dir = query_dir_template.format(f'{t}_jo')
    print(f"Executing query {query_dir}")
    if os.path.isdir(query_dir):
        pg_db = DB_instance(engine_name, db_name)
        pg_ev = Runtime_Evaluator(pg_db, query_dir)
        pg_ev.evaluate_queries(sql_dir=query_dir,
                               # sql_files=job_slow_queries,
                               # skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                               save_json_file=f'./eval_join_group/{engine_name}_balsa_slow_test_take{t}_jo_runtimes.json', 
                              rerun_finished=True,
                              disable_parallel=False,
                              multiple_runs=2,
                              save_plan=False)
    break
# Out:
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_slow_test/take5_jo/
# INFO:root:Evaluating 10c.sql.
# INFO:root:	Finished the 1-th trial with 5.45 secs
# INFO:root:	Finished the 2-th trial with 5.11 secs
# INFO:root:	Avg runtime = 5.28 secs
# INFO:root:Evaluating 16b.sql.
# INFO:root:	Finished the 1-th trial with 5.95 secs
# INFO:root:	Finished the 2-th trial with 5.85 secs
# INFO:root:	Avg runtime = 5.90 secs
# INFO:root:Evaluating 17a.sql.
# INFO:root:	Finished the 1-th trial with 6.04 secs
# INFO:root:	Finished the 2-th trial with 5.97 secs
# INFO:root:	Avg runtime = 6.01 secs
# INFO:root:Evaluating 17b.sql.
# INFO:root:	Finished the 1-th trial with 0.60 secs
# INFO:root:	Finished the 2-th trial with 0.60 secs
# INFO:root:	Avg runtime = 0.60 secs
# INFO:root:Evaluating 17c.sql.
# INFO:root:	Finished the 1-th trial with 0.47 secs
# INFO:root:	Finished the 2-th trial with 0.49 secs
# INFO:root:	Avg runtime = 0.48 secs
# INFO:root:Evaluating 17d.sql.
# ...

# %% [markdown]
# # Balsa rand split

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_rand_test']

for t in range(1, 5):
    query_dir = query_dir_template.format(t)
    print(f"Executing query {query_dir}")
    if os.path.isdir(query_dir):
        pg_db = DB_instance(engine_name, db_name)
        pg_ev = Runtime_Evaluator(pg_db, query_dir)
        pg_ev.evaluate_queries(sql_dir=query_dir,
                               # sql_files=job_slow_queries,
                               # skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                               save_json_file=f'./eval_join_group/{engine_name}_balsa_rand_test_take{t}_runtimes.json', 
                              rerun_finished=True,
                              disable_parallel=False,
                              multiple_runs=2,
                              save_plan=False)
# Out:
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_rand_test/take1/
# INFO:root:Evaluating 10a.sql.
# INFO:root:	Finished the 1-th trial with 7.59 secs
# INFO:root:	Finished the 2-th trial with 5.36 secs
# INFO:root:	Avg runtime = 6.48 secs
# INFO:root:Evaluating 10b.sql.
# INFO:root:	Finished the 1-th trial with 7.65 secs
# INFO:root:	Finished the 2-th trial with 7.50 secs
# INFO:root:	Avg runtime = 7.57 secs
# INFO:root:Evaluating 12b.sql.
# INFO:root:	Finished the 1-th trial with 6.10 secs
# INFO:root:	Finished the 2-th trial with 6.03 secs
# INFO:root:	Avg runtime = 6.06 secs
# INFO:root:Evaluating 15a.sql.
# INFO:root:	Finished the 1-th trial with 96.36 secs
# INFO:root:	Finished the 2-th trial with 95.65 secs
# INFO:root:	Avg runtime = 96.00 secs
# INFO:root:Evaluating 15b.sql.
# INFO:root:	Finished the 1-th trial with 2.46 secs
# INFO:root:	Finished the 2-th trial with 2.45 secs
# INFO:root:	Avg runtime = 2.46 secs
# INFO:root:Evaluating 15d.sql.
# ...

# %% [markdown]
# ### JO

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_rand_test']

# for group in range(1, 7): #, '17a']:
for take in range(1, 5):
    query_dir = query_dir_template.format(f'{take}')
    jo_query_dir = query_dir_template.format(f'{take}_jo')

    if os.path.isdir(query_dir):
        for fname in os.listdir(query_dir):
            if 'sql' in fname:
                with open(os.path.join(query_dir, fname)) as f, open(os.path.join(jo_query_dir, fname), 'w') as g:
                    line = f.readline()
                    while line:
                        # print(line)
                        if 'HashJoin' in line or 'NestLoop' in line or 'MergeJoin' in line or 'SeqScan' in line or 'IndexScan' in line:
                            if '/*+' in line:
                                g.write('/*+\n')
                                # print('/*+\n')
                        else:
                            g.write(line)
                            # print(line)
                        line = f.readline()
        pass
    else:
        print(query_dir, ' not found.')

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_rand_test']

for t in range(1, 5):
    query_dir = query_dir_template.format(f'{t}_jo')
    print(f"Executing query {query_dir}")
    if os.path.isdir(query_dir):
        pg_db = DB_instance(engine_name, db_name)
        pg_ev = Runtime_Evaluator(pg_db, query_dir)
        pg_ev.evaluate_queries(sql_dir=query_dir,
                               # sql_files=job_slow_queries,
                               # skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                               save_json_file=f'./eval_join_group/{engine_name}_balsa_rand_test_jo_take{t}_runtimes.json', 
                              rerun_finished=True,
                              disable_parallel=False,
                              multiple_runs=2,
                              save_plan=False)
# Out:
# Executing query /mnt/pg_lip_bloom/queries/job_balsa_rand_test/take1_jo/
# INFO:root:Evaluating 10a.sql.
# INFO:root:	Finished the 1-th trial with 4.24 secs
# INFO:root:	Finished the 2-th trial with 3.73 secs
# INFO:root:	Avg runtime = 3.98 secs
# INFO:root:Evaluating 10b.sql.
# INFO:root:	Finished the 1-th trial with 2.34 secs
# INFO:root:	Finished the 2-th trial with 2.26 secs
# INFO:root:	Avg runtime = 2.30 secs
# INFO:root:Evaluating 12b.sql.
# INFO:root:	Finished the 1-th trial with 1.46 secs
# INFO:root:	Finished the 2-th trial with 1.42 secs
# INFO:root:	Avg runtime = 1.44 secs
# INFO:root:Evaluating 15a.sql.
# INFO:root:	Finished the 1-th trial with 5.07 secs
# INFO:root:	Finished the 2-th trial with 4.79 secs
# INFO:root:	Avg runtime = 4.93 secs
# INFO:root:Evaluating 15b.sql.
# INFO:root:	Finished the 1-th trial with 0.55 secs
# INFO:root:	Finished the 2-th trial with 0.54 secs
# INFO:root:	Avg runtime = 0.55 secs
# INFO:root:Evaluating 15d.sql.
# ...

# %% [markdown]
# # Balsa test join group

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_eval_join_group']

for g in range(1, 7): #, '17a']:
    for t in range(1, 5):
        query_dir = query_dir_template.format(g, t)
        print(f"Executing query {query_dir}")
        if os.path.isdir(query_dir):
            pg_db = DB_instance(engine_name, db_name)
            pg_ev = Runtime_Evaluator(pg_db, query_dir)
            pg_ev.evaluate_queries(sql_dir=query_dir,
                                   # sql_files=job_slow_queries,
                                   # skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                                   save_json_file=f'./eval_join_group/{engine_name}_balsa_eval_join_group{g}_take{t}_runtimes.json', 
                                  rerun_finished=False,
                                  disable_parallel=False,
                                  multiple_runs=2,
                                  save_plan=False)
# Out:
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_1/take1/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_1/take2/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_1/take3/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_1/take4/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_2/take1/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_2/take2/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_2/take3/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_2/take4/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_3/take1/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_3/take2/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_3/take3/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_3/take4/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_4/take1/
# ...

# %% [markdown]
# # Balsa test join group JO

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_eval_join_group']

for group in range(1, 7): #, '17a']:
    for take in range(1, 5):
        query_dir = query_dir_template.format(group, f'{take}')
        jo_query_dir = query_dir_template.format(group, f'{take}_jo')
        # print(jo_query_dir)
        
        if os.path.isdir(query_dir):
            for fname in os.listdir(query_dir):
                if 'sql' in fname:
                    with open(os.path.join(query_dir, fname)) as f, open(os.path.join(jo_query_dir, fname), 'w') as g:
                        line = f.readline()
                        while line:
                            # print(line)
                            if 'HashJoin' in line or 'NestLoop' in line or 'MergeJoin' in line or 'SeqScan' in line or 'IndexScan' in line:
                                if '/*+' in line:
                                    g.write('/*+\n')
                                    # print('/*+\n')
                            else:
                                g.write(line)
                                # print(line)
                            line = f.readline()
            pass
        else:
            print(query_dir, ' not found.')
# Out:
# /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_6/take4/  not found.

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_eval_join_group']

for g in range(1, 7): #, '17a']:
    for t in range(1, 5):
        query_dir = query_dir_template.format(g, f'{t}_jo')
        print(f"Executing query {query_dir}")
        if os.path.isdir(query_dir):
            pg_db = DB_instance(engine_name, db_name)
            pg_ev = Runtime_Evaluator(pg_db, query_dir)
            pg_ev.evaluate_queries(sql_dir=query_dir,
                                   # sql_files=job_slow_queries,
                                   # skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                                   save_json_file=f'./eval_join_group/{engine_name}_balsa_eval_join_group{g}_take{t}_jo_runtimes.json', 
                                  rerun_finished=False,
                                  disable_parallel=False,
                                  multiple_runs=2,
                                  save_plan=False)
# Out:
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_1/take1_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_1/take2_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_1/take3_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_1/take4_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_2/take1_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_2/take2_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_2/take3_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_2/take4_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_3/take1_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_3/take2_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_3/take3_jo/
# Executing query /mnt/pg_lip_bloom/queries/JOB_test_n_join_group_3/take4_jo/
# ...

# %% [markdown]
# # PG Balsa test cost model

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_eval_cost_model']

for q in ['10a', '10c']: #, '17a']:
    query_dir = query_dir_template.format(q)
    print(f"Executing query {q}")

    pg_db = DB_instance(engine_name, db_name)
    pg_ev = Runtime_Evaluator(pg_db, query_dir)
    pg_ev.evaluate_queries(sql_dir=query_dir,
                           # sql_files=job_slow_queries,
                           skip_queries=['17a_108.sql', '17a_115.sql', '17a_179.sql'],
                           save_json_file=f'./eval_cost_model/{engine_name}_balsa_eval_cost_model_{q}_runtimes.json', 
                          rerun_finished=False,
                          disable_parallel=False,
                          multiple_runs=2,
                          save_plan=False)
# Out:
# Executing query 10a
# INFO:root:Evaluating 10a_72.sql.
# INFO:root:	Finished the 1-th trial with 46.10 secs
# INFO:root:	Finished the 2-th trial with 44.06 secs
# INFO:root:	Avg runtime = 45.08 secs
# INFO:root:Evaluating 10a_73.sql.
# INFO:root:	Finished the 1-th trial with 7.61 secs
# INFO:root:	Finished the 2-th trial with 7.44 secs
# INFO:root:	Avg runtime = 7.52 secs
# INFO:root:Evaluating 10a_74.sql.
# INFO:root:	Finished the 1-th trial with 8.16 secs
# INFO:root:	Finished the 2-th trial with 7.91 secs
# INFO:root:	Avg runtime = 8.04 secs
# INFO:root:Evaluating 10a_75.sql.
# INFO:root:	Finished the 1-th trial with 3.51 secs
# INFO:root:	Finished the 2-th trial with 3.15 secs
# INFO:root:	Avg runtime = 3.33 secs
# INFO:root:Evaluating 10a_76.sql.
# INFO:root:	Finished the 1-th trial with 5.44 secs
# INFO:root:	Finished the 2-th trial with 6.00 secs
# INFO:root:	Avg runtime = 5.72 secs
# INFO:root:Evaluating 10a_77.sql.
# INFO:root:	Finished the 1-th trial with 4.00 secs
# ...

# %% [markdown]
# # PG Balsa test cost model (Balsa touched)

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_eval_cost_model_touched']

for q in ['17a']: #, '17a']:
    query_dir = query_dir_template.format(q)
    print(f"Executing query {q}")

    pg_db = DB_instance(engine_name, db_name)
    pg_ev = Runtime_Evaluator(pg_db, query_dir)
    pg_ev.evaluate_queries(sql_dir=query_dir,
                           # sql_files=job_slow_queries,
                           skip_queries=['17a_1.sql'],
                           save_json_file=f'./eval_cost_model/{engine_name}_balsa_eval_cost_model_{q}_balsa_touched_runtimes.json', 
                          rerun_finished=False,
                          disable_parallel=False,
                          multiple_runs=2,
                          save_plan=False)
# Out:
# Executing query 17a
# INFO:root:Evaluating 17a_10.sql.
# INFO:root:	Finished the 1-th trial with 15.07 secs
# INFO:root:	Finished the 2-th trial with 13.34 secs
# INFO:root:	Avg runtime = 14.20 secs
# INFO:root:Evaluating 17a_100.sql.
# INFO:root:	Finished the 1-th trial with 518.15 secs
# INFO:root:	Finished the 2-th trial with 264.87 secs
# INFO:root:	Avg runtime = 391.51 secs
# INFO:root:Evaluating 17a_11.sql.
# INFO:root:	Finished the 1-th trial with 17.48 secs

# %% [markdown]
# # PG Balsa test join group

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir_template = query_dirs['imdb_balsa_test_join_group']

for g in [f'{i}' for i in range(2, 3)]:
    for t in range(1, 5):
        query_dir = query_dir_template.format(g, t)
        print(f"Executing group {g} take {t}")
        pg_db = DB_instance(engine_name, db_name)
        pg_ev = Runtime_Evaluator(pg_db, query_dir)
        pg_ev.evaluate_queries(sql_dir=query_dir,
                               # sql_files=job_slow_queries,
                               # skip_queries=['17c.sql', '20a.sql'],
                               save_json_file=f'./{engine_name}_balsa_test_join_group{g}_take{t}_parallel=1_{db_name}_runtimes.json', 
                              rerun_finished=True,
                              disable_parallel=False,
                              multiple_runs=2,
                              save_plan=False)
# Out:
# Executing group 2 take 1
# INFO:root:Evaluating t_10a.sql.
# INFO:root:	Finished the 1-th trial with 1.89 secs
# INFO:root:	Finished the 2-th trial with 1.87 secs
# INFO:root:	Avg runtime = 1.88 secs
# INFO:root:Evaluating t_10b.sql.
# INFO:root:	Finished the 1-th trial with 1.68 secs
# INFO:root:	Finished the 2-th trial with 1.67 secs
# INFO:root:	Avg runtime = 1.67 secs
# INFO:root:Evaluating t_10c.sql.
# INFO:root:	Finished the 1-th trial with 1.75 secs
# INFO:root:	Finished the 2-th trial with 1.84 secs
# INFO:root:	Avg runtime = 1.79 secs
# INFO:root:Evaluating t_17a.sql.
# INFO:root:	Finished the 1-th trial with 4.59 secs
# INFO:root:	Finished the 2-th trial with 4.21 secs
# INFO:root:	Avg runtime = 4.40 secs
# INFO:root:Evaluating t_17b.sql.
# INFO:root:	Finished the 1-th trial with 2.01 secs
# INFO:root:	Finished the 2-th trial with 2.00 secs
# INFO:root:	Avg runtime = 2.01 secs
# INFO:root:Evaluating t_17c.sql.
# INFO:root:	Finished the 1-th trial with 2.00 secs
# ...

# %% [markdown]
# # PG disable NL

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       # sql_files=job_slow_queries,
                       # skip_queries=['21a.sql', '21b.sql', '21c.sql', '24a.sql', '27a.sql', '27b.sql', '27d.sql', '27c.sql'],
                      save_json_file=f'./{engine_name}_parallel=1_{db_name}_disable_nl_runtimes.json', 
                      rerun_finished=True,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=False,
                      disable_op='nestloop')
# Out:
# INFO:root:Evaluating 10a.sql.
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 1-th trial with 1.92 secs
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 2-th trial with 1.82 secs
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 3-th trial with 1.79 secs
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 4-th trial with 1.78 secs
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 5-th trial with 1.79 secs
# INFO:root:	Avg runtime = 1.82 secs
# INFO:root:Evaluating 10b.sql.
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 1-th trial with 1.98 secs
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 2-th trial with 1.98 secs
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 3-th trial with 1.94 secs
# WARNING:root:nestloop join is disabled.
# INFO:root:	Finished the 4-th trial with 1.94 secs
# WARNING:root:nestloop join is disabled.
# ...

# %% [markdown]
# # PG disable MJ

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       # sql_files=job_slow_queries,
                       # skip_queries=['21a.sql', '21b.sql', '21c.sql', '24a.sql', '27a.sql', '27b.sql', '27d.sql', '27c.sql'],
                      save_json_file=f'./{engine_name}_parallel=1_{db_name}_disable_mj_runtimes.json', 
                      rerun_finished=True,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=False,
                      disable_op='mergejoin')
# Out:
# INFO:root:Evaluating 10a.sql.
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 1-th trial with 0.37 secs
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 2-th trial with 0.35 secs
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 3-th trial with 0.34 secs
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 4-th trial with 0.32 secs
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 5-th trial with 0.33 secs
# INFO:root:	Avg runtime = 0.34 secs
# INFO:root:Evaluating 10b.sql.
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 1-th trial with 0.23 secs
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 2-th trial with 0.23 secs
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 3-th trial with 0.22 secs
# WARNING:root:mergejoin join is disabled.
# INFO:root:	Finished the 4-th trial with 0.22 secs
# WARNING:root:mergejoin join is disabled.
# ...

# %% [markdown]
# # PG disable both MJ and NL

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       # sql_files=job_slow_queries,
                       # skip_queries=['21a.sql', '21b.sql', '21c.sql', '24a.sql', '27a.sql', '27b.sql', '27d.sql', '27c.sql'],
                      save_json_file=f'./{engine_name}_parallel=1_{db_name}_disable_nl_mj_runtimes.json', 
                      rerun_finished=True,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=False,
                      disable_op='both')
# Out:
# INFO:root:Evaluating 10a.sql.
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 1-th trial with 1.89 secs
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 2-th trial with 1.86 secs
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 3-th trial with 1.79 secs
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 4-th trial with 1.82 secs
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 5-th trial with 1.77 secs
# INFO:root:	Avg runtime = 1.82 secs
# INFO:root:Evaluating 10b.sql.
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 1-th trial with 1.95 secs
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 2-th trial with 1.93 secs
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 3-th trial with 1.95 secs
# WARNING:root:both join is disabled.
# INFO:root:	Finished the 4-th trial with 1.92 secs
# WARNING:root:both join is disabled.
# ...

# %% [markdown]
# # PG disable NL + balsa

# %%
engine_name = 'postgres'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_balsa']

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(sql_dir=query_dir,
                       sql_files=job_slow_queries,
                       skip_queries=['17c.sql', 'c.sql'],
                       save_json_file=f'./{engine_name}_parallel=1_{db_name}_balsa_disable_nl_runtimes.json', 
                      rerun_finished=True,
                      disable_parallel=False,
                      multiple_runs=5,
                      save_plan=True,
                      disable_nestloop=True)
# Out:
# INFO:root:Evaluating 6d.sql.
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 1-th trial with 11.76 secs
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 2-th trial with 8.89 secs
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 3-th trial with 8.94 secs
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 4-th trial with 8.98 secs
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 5-th trial with 9.00 secs
# INFO:root:	Avg runtime = 9.52 secs
# INFO:root:Evaluating 6f.sql.
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 1-th trial with 9.51 secs
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 2-th trial with 9.46 secs
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 3-th trial with 9.52 secs
# WARNING:root:Nested loop join is disabled.
# INFO:root:	Finished the 4-th trial with 9.62 secs
# ...

# %% [markdown]
# # PG disable NL + LIP

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = query_dirs['imdb_pg_lip']
init_sql_file= '/mnt/ml4qo/lip_db/lip_db_test_queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
    save_json_file=f'./{engine_name}_parallel=1_{db_name}_disable_nl_runtimes.json', 
                      sql_files=job_slow_queries,
                      rerun_finished=True,
                      disable_parallel=False, 
                      multiple_runs=5, 
                      save_plan=True,
                      disable_nestloop=True)
# Out:
# INFO:root:Evaluating 6d.sql.
# INFO:root:	Finished the 1-th trial with total: 3.63 secs, (prep: 1.51, exec: 2.11)
# INFO:root:	Finished the 2-th trial with total: 3.29 secs, (prep: 1.19, exec: 2.10)
# INFO:root:	Finished the 3-th trial with total: 3.33 secs, (prep: 1.21, exec: 2.12)
# INFO:root:	Finished the 4-th trial with total: 3.20 secs, (prep: 1.18, exec: 2.02)
# INFO:root:	Finished the 5-th trial with total: 3.25 secs, (prep: 1.20, exec: 2.05)
# INFO:root:Evaluating 6f.sql.
# INFO:root:	Finished the 1-th trial with total: 5.16 secs, (prep: 0.68, exec: 4.48)
# INFO:root:	Finished the 2-th trial with total: 5.17 secs, (prep: 0.69, exec: 4.48)
# INFO:root:	Finished the 3-th trial with total: 5.18 secs, (prep: 0.69, exec: 4.49)
# INFO:root:	Finished the 4-th trial with total: 5.23 secs, (prep: 0.67, exec: 4.55)
# INFO:root:	Finished the 5-th trial with total: 5.13 secs, (prep: 0.69, exec: 4.43)
# INFO:root:Evaluating 8c.sql.
# ...

# %% [markdown]
# # Test UDF and BF overheads

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = '/mnt/pg_lip_bloom/queries/job_pg_lip_test_overhead/bf_static_probe_overhead/'
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./eval_overhead/{engine_name}_static_build_parallel=1_{db_name}_bf_static_probe_overhead_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      multiple_runs=3, 
                      save_plan=False)
# Out:
# INFO:root:Evaluating 6d.sql.
# INFO:root:	Finished the 1-th trial with total: 5.62 secs, (prep: 1.33, exec: 4.30)
# INFO:root:	Finished the 2-th trial with total: 4.81 secs, (prep: 1.25, exec: 3.56)
# INFO:root:	Finished the 3-th trial with total: 4.95 secs, (prep: 1.25, exec: 3.69)
# INFO:root:Evaluating 6f.sql.
# INFO:root:	Finished the 1-th trial with total: 4.23 secs, (prep: 0.82, exec: 3.41)
# INFO:root:	Finished the 2-th trial with total: 4.25 secs, (prep: 0.83, exec: 3.42)
# INFO:root:	Finished the 3-th trial with total: 5.28 secs, (prep: 0.82, exec: 4.47)
# INFO:root:Evaluating 8c.sql.
# INFO:root:	Finished the 1-th trial with total: 3.42 secs, (prep: 0.44, exec: 2.98)
# INFO:root:	Finished the 2-th trial with total: 3.40 secs, (prep: 0.43, exec: 2.97)
# INFO:root:	Finished the 3-th trial with total: 3.36 secs, (prep: 0.44, exec: 2.92)
# INFO:root:Evaluating 9d.sql.
# INFO:root:	Finished the 1-th trial with total: 7.52 secs, (prep: 2.78, exec: 4.73)
# ...

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = '/mnt/pg_lip_bloom/queries/job_pg_lip_test_overhead/bf_dynamic_probe_overhead/'
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./eval_overhead/{engine_name}_adaptive_build_parallel=1_{db_name}_bf_dynamic_probe_overhead_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=False,
                      multiple_runs=3, 
                      save_plan=False)

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = '/mnt/pg_lip_bloom/queries/job_pg_lip_test_overhead/bf_static_build_dynamic_probe_overhead/'
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./eval_overhead/{engine_name}_static_build_parallel=1_{db_name}_bf_dynamic_probe_overhead_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      multiple_runs=3, 
                      save_plan=False)

# %%
engine_name = 'postgres_pg_lip'
# db_name = 'imdb'
db_name = 'imdbload'
query_dir = '/mnt/pg_lip_bloom/queries/job_pg_lip_test_overhead/func_call_overhead'
init_sql_file= '/mnt/pg_lip_bloom/queries/lip_bloom_init.sql'

pg_db = DB_instance(engine_name, db_name)
pg_ev = PG_LIP_Runtime_Evaluator(pg_db, query_dir, init_sql_file=init_sql_file)
pg_ev.evaluate_queries(sql_dir=query_dir,
                      save_json_file=  f'./eval_overhead/{engine_name}_adaptive_build_parallel=1_{db_name}_func_call_overhead_runtimes.json', 
                      sql_files= job_slow_queries,
                      rerun_finished=True,
                      multiple_runs=3, 
                      save_plan=False)
# Out:
# INFO:root:Evaluating 6d.sql.
# INFO:root:	Finished the 1-th trial with total: 4.83 secs, (prep: 0.80, exec: 4.03)
# INFO:root:	Finished the 2-th trial with total: 4.12 secs, (prep: 0.75, exec: 3.37)
# INFO:root:	Finished the 3-th trial with total: 4.12 secs, (prep: 0.77, exec: 3.35)
# INFO:root:Evaluating 6f.sql.
# INFO:root:	Finished the 1-th trial with total: 3.61 secs, (prep: 0.35, exec: 3.27)
# INFO:root:	Finished the 2-th trial with total: 3.59 secs, (prep: 0.34, exec: 3.25)
# INFO:root:	Finished the 3-th trial with total: 3.76 secs, (prep: 0.34, exec: 3.42)
# INFO:root:Evaluating 8c.sql.
# INFO:root:	Finished the 1-th trial with total: 3.36 secs, (prep: 0.36, exec: 3.00)
# INFO:root:	Finished the 2-th trial with total: 3.32 secs, (prep: 0.34, exec: 2.98)
# INFO:root:	Finished the 3-th trial with total: 3.19 secs, (prep: 0.34, exec: 2.85)
# INFO:root:Evaluating 9d.sql.
# INFO:root:	Finished the 1-th trial with total: 3.23 secs, (prep: 0.68, exec: 2.55)
# ...

# %% [markdown]
# # SQLite

# %%
engine_name = 'sqlite'
db_name = 'imdb'
query_name = db_name
query_dir = query_dirs[query_name]

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(save_json_file=f'./{engine_name}_{db_name}_runtimes.json',
                       rerun_finished=True,
                    multiple_runs=5, 
                       timeout=600,
                      disable_lip=False)
# Out:
# INFO:root:Evaluating 10a.sql.
# QUERY PLAN
# |--SCAN mc
# |--BLOOM FILTER ON cn (id=?)
# |--SEARCH cn USING INTEGER PRIMARY KEY (rowid=?)
# |--SEARCH t USING INTEGER PRIMARY KEY (rowid=?)
# |--SEARCH ci USING AUTOMATIC PARTIAL COVERING INDEX (movie_id=?)
# |--SEARCH ct USING INTEGER PRIMARY KEY (rowid=?)
# |--SEARCH chn USING INTEGER PRIMARY KEY (rowid=?)
# |--BLOOM FILTER ON rt (id=?)
# `--SEARCH rt USING INTEGER PRIMARY KEY (rowid=?)
# Actor|12 Rounds
# INFO:root:	Finished the 1-th trial with 3.22 secs
# Actor|12 Rounds
# INFO:root:	Finished the 2-th trial with 3.24 secs
# Actor|12 Rounds
# INFO:root:	Finished the 3-th trial with 3.29 secs
# Actor|12 Rounds
# INFO:root:	Finished the 4-th trial with 3.29 secs
# Actor|12 Rounds
# INFO:root:	Finished the 5-th trial with 3.29 secs
# INFO:root:	Avg runtime = 3.27 secs
# INFO:root:Evaluating 10b.sql.
# QUERY PLAN
# |--SCAN mc
# |--BLOOM FILTER ON cn (id=?)
# |--SEARCH cn USING INTEGER PRIMARY KEY (rowid=?)
# ...

# %%
engine_name = 'sqlite'
db_name = 'imdb_fk'
query_name = db_name
query_dir = query_dirs[query_name]

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(save_json_file=f'./{engine_name}_{db_name}_runtimes.json',
                       rerun_finished=True,
                    multiple_runs=5, 
                       timeout=600,
                      disable_lip=False)
# Out:
# INFO:root:Evaluating 10a.sql.
# QUERY PLAN
# |--SCAN cn
# |--SEARCH mc USING INDEX company_id_movie_companies (company_id=?)
# |--SEARCH t USING INDEX sqlite_autoindex_title_1 (id=?)
# |--SEARCH ci USING INDEX movie_id_cast_info (movie_id=?)
# |--SEARCH chn USING INDEX sqlite_autoindex_char_name_1 (id=?)
# |--BLOOM FILTER ON rt (id=?)
# |--SEARCH rt USING INDEX sqlite_autoindex_role_type_1 (id=?)
# `--SEARCH ct USING COVERING INDEX sqlite_autoindex_company_type_1 (id=?)
# Actor|12 Rounds
# INFO:root:	Finished the 1-th trial with 0.90 secs
# Actor|12 Rounds
# INFO:root:	Finished the 2-th trial with 0.88 secs
# Actor|12 Rounds
# INFO:root:	Finished the 3-th trial with 0.88 secs
# Actor|12 Rounds
# INFO:root:	Finished the 4-th trial with 0.88 secs
# Actor|12 Rounds
# INFO:root:	Finished the 5-th trial with 0.98 secs
# INFO:root:	Avg runtime = 0.91 secs
# INFO:root:Evaluating 10b.sql.
# QUERY PLAN
# |--SCAN cn
# |--SEARCH mc USING INDEX company_id_movie_companies (company_id=?)
# ...

# %%
engine_name = 'sqlite'
db_name = 'tpch_sf1'
query_dir = query_dirs[db_name]

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(save_json_file=f'./{engine_name}_{db_name}_runtimes.json',
                       rerun_finished=True,
                      multiple_runs=5, 
                       timeout=600,
                      disable_lip=False)
# Out:
# INFO:root:Evaluating 1.sql.
# QUERY PLAN
# `--SCAN lineitem
# 5914748
# INFO:root:	Finished the 1-th trial with 1.04 secs
# 5914748
# INFO:root:	Finished the 2-th trial with 1.08 secs
# 5914748
# INFO:root:	Finished the 3-th trial with 1.03 secs
# 5914748
# INFO:root:	Finished the 4-th trial with 1.03 secs
# 5914748
# INFO:root:	Finished the 5-th trial with 1.08 secs
# INFO:root:	Avg runtime = 1.05 secs
# INFO:root:Evaluating 10.sql.
# QUERY PLAN
# |--SCAN lineitem
# |--SEARCH orders USING INDEX sqlite_autoindex_orders_1 (o_orderkey=?)
# |--SEARCH customer USING INDEX sqlite_autoindex_customer_1 (c_custkey=?)
# `--SEARCH nation USING COVERING INDEX sqlite_autoindex_nation_1 (n_nationkey=?)
# 114705
# INFO:root:	Finished the 1-th trial with 1.91 secs
# 114705
# INFO:root:	Finished the 2-th trial with 1.89 secs
# 114705
# INFO:root:	Finished the 3-th trial with 1.89 secs
# 114705
# INFO:root:	Finished the 4-th trial with 1.88 secs
# 114705
# ...

# %% [markdown]
# ## sqlite w/o lip

# %%
engine_name = 'sqlite'
db_name = 'imdb'
query_name = 'imdb'
query_dir = query_dirs[query_name]

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(save_json_file=f'./{engine_name}_{db_name}_wo_lip_runtimes.json',
                       rerun_finished=True,
                    multiple_runs=5, 
                       timeout=600,
                      disable_lip=True)
# Out:
# INFO:root:Evaluating 10a.sql.
# INFO:root:LIP optimization is disabled.
# QUERY PLAN
# |--SCAN mc
# |--SEARCH cn USING INTEGER PRIMARY KEY (rowid=?)
# |--SEARCH t USING INTEGER PRIMARY KEY (rowid=?)
# |--SEARCH ci USING AUTOMATIC PARTIAL COVERING INDEX (movie_id=?)
# |--SEARCH ct USING INTEGER PRIMARY KEY (rowid=?)
# |--SEARCH chn USING INTEGER PRIMARY KEY (rowid=?)
# `--SEARCH rt USING INTEGER PRIMARY KEY (rowid=?)
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 1-th trial with 4.94 secs
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 2-th trial with 5.02 secs
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 3-th trial with 4.92 secs
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 4-th trial with 4.96 secs
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 5-th trial with 4.91 secs
# ...

# %%
engine_name = 'sqlite'
db_name = 'imdb_fk'
query_name = 'imdb_fk'
query_dir = query_dirs[query_name]

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(save_json_file=f'./{engine_name}_{db_name}_wo_lip_runtimes.json',
                       rerun_finished=True,
                    multiple_runs=5, 
                       timeout=600,
                      disable_lip=True)
# Out:
# INFO:root:Evaluating 10a.sql.
# INFO:root:LIP optimization is disabled.
# QUERY PLAN
# |--SCAN cn
# |--SEARCH mc USING INDEX company_id_movie_companies (company_id=?)
# |--SEARCH t USING INDEX sqlite_autoindex_title_1 (id=?)
# |--SEARCH ci USING INDEX movie_id_cast_info (movie_id=?)
# |--SEARCH chn USING INDEX sqlite_autoindex_char_name_1 (id=?)
# |--SEARCH rt USING INDEX sqlite_autoindex_role_type_1 (id=?)
# `--SEARCH ct USING COVERING INDEX sqlite_autoindex_company_type_1 (id=?)
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 1-th trial with 0.98 secs
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 2-th trial with 0.90 secs
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 3-th trial with 1.05 secs
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# INFO:root:	Finished the 4-th trial with 1.00 secs
# INFO:root:LIP optimization is disabled.
# Actor|12 Rounds
# ...

# %%
engine_name = 'sqlite'
db_name = 'tpch_sf1'
query_dir = query_dirs[db_name]

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(save_json_file=f'./{engine_name}_{db_name}_wo_lip_runtimes.json',
                       rerun_finished=True,
                      multiple_runs=5, 
                       timeout=600,
                      disable_lip=True)
# Out:
# INFO:root:Evaluating 1.sql.
# INFO:root:LIP optimization is disabled.
# QUERY PLAN
# `--SCAN lineitem
# INFO:root:LIP optimization is disabled.
# 5914748
# INFO:root:	Finished the 1-th trial with 1.08 secs
# INFO:root:LIP optimization is disabled.
# 5914748
# INFO:root:	Finished the 2-th trial with 1.05 secs
# INFO:root:LIP optimization is disabled.
# 5914748
# INFO:root:	Finished the 3-th trial with 1.05 secs
# INFO:root:LIP optimization is disabled.
# 5914748
# INFO:root:	Finished the 4-th trial with 1.05 secs
# INFO:root:LIP optimization is disabled.
# 5914748
# INFO:root:	Finished the 5-th trial with 1.04 secs
# INFO:root:	Avg runtime = 1.05 secs
# INFO:root:Evaluating 10.sql.
# INFO:root:LIP optimization is disabled.
# QUERY PLAN
# |--SCAN lineitem
# |--SEARCH orders USING INDEX sqlite_autoindex_orders_1 (o_orderkey=?)
# |--SEARCH customer USING INDEX sqlite_autoindex_customer_1 (c_custkey=?)
# `--SEARCH nation USING COVERING INDEX sqlite_autoindex_nation_1 (n_nationkey=?)
# ...

# %%
engine_name = 'sqlite'
db_name = 'tpch_sf1'
query_dir = query_dirs[db_name]

pg_db = DB_instance(engine_name, db_name)
pg_ev = Runtime_Evaluator(pg_db, query_dir)
pg_ev.evaluate_queries(save_json_file=f'./{engine_name}_{db_name}_runtimes.json',rerun_finished=False)
# Out:
# INFO:root:Evaluating 7.sql.
# INFO:root:	Finished the 1-th trial with 5.80 secs
# INFO:root:	Finished the 2-th trial with 5.75 secs
# INFO:root:	Finished the 3-th trial with 5.85 secs
# INFO:root:	Finished the 4-th trial with 5.76 secs
# INFO:root:	Finished the 5-th trial with 5.81 secs
# INFO:root:	Avg runtime = 5.80 secs
# {'1.sql': [0.8868951797485352,
#   0.883683443069458,
#   0.8764975070953369,
#   0.8876726627349854,
#   0.8772170543670654],
#  '10.sql': [0.7575156688690186,
#   0.7581968307495117,
#   0.7640976905822754,
#   0.7750651836395264,
#   0.7648313045501709],
#  '11.sql': [0.0033881664276123047,
#   0.0029549598693847656,
#   0.002863645553588867,
#   0.0028073787689208984,
#   0.0028142929077148438],
#  '12.sql': [2.4025447368621826,
#   2.342451572418213,
#   2.3847224712371826,
#   2.4203243255615234,
#   2.4067959785461426],
#  '13.sql': [4.837942123413086,
#   4.933394432067871,
#   4.905344724655151,
#   4.917284965515137,
#   4.978180408477783],
# ...

# %%
import pandas 
df = pd.read_csv('/mnt/ml4qo/baseline/ssb-benchmark/results.csv')
est_quality = {}
for i in range(15):
    actual_rows = int(df['cardinality_true'].iloc[i])
    est_rows = int(df['cardinality_predict'].iloc[i] * 50)
    q_error = max(actual_rows / est_rows, est_rows / actual_rows)
    est_quality[f'{i+1}.sql'] = {
                'actual': actual_rows, 
                'estimated': est_rows,
                'estimation diff': '{0:+}'.format(est_rows - actual_rows),
                'q-error': q_error
                }
print(est_quality)
import json
with open('./eval_results/deepdb_ssb_sf10.json', 'w') as outfile:
    json.dump(est_quality, outfile, indent=4)
# Out:
# {'1.sql': {'actual': 42209, 'estimated': 35274, 'estimation diff': '-6935', 'q-error': 1.196603730793219}, '2.sql': {'actual': 1193001, 'estimated': 993200, 'estimation diff': '-199801', 'q-error': 1.2011689488521948}, '3.sql': {'actual': 42209, 'estimated': 35274, 'estimation diff': '-6935', 'q-error': 1.196603730793219}, '4.sql': {'actual': 9488, 'estimated': 7952, 'estimation diff': '-1536', 'q-error': 1.193158953722334}, '5.sql': {'actual': 9488, 'estimated': 7952, 'estimation diff': '-1536', 'q-error': 1.193158953722334}, '6.sql': {'actual': 490740, 'estimated': 409051, 'estimation diff': '-81689', 'q-error': 1.1997037044280543}, '7.sql': {'actual': 94856, 'estimated': 80084, 'estimation diff': '-14772', 'q-error': 1.1844563208630938}, '8.sql': {'actual': 11847, 'estimated': 9780, 'estimation diff': '-2067', 'q-error': 1.2113496932515337}, '9.sql': {'actual': 2199936, 'estimated': 1836820, 'estimation diff': '-363116', 'q-error': 1.1976873074117225}, '10.sql': {'actual': 87646, 
# ...
